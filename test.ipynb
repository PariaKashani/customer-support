# %%
import shutil
import uuid

from src.agent import CustomerSupportAgent


db = "travel2.sqlite"
backup_file = "travel2.backup.sqlite"

shutil.copy(backup_file, db)
thread_id = str(uuid.uuid4())

config = {
    "configurable": {
        # The passenger_id is used in our flight tools to
        # fetch the user's flight information
        "passenger_id": "3442 587242",
        # Checkpoints are accessed by thread_id
        "thread_id": thread_id,
}
}

questions = [
    "سلام، پرواز من چه زمانی است؟",
    "آیا اجازه دارم پروازم رو به زمانی زودتر موکول کنم؟ من دوست دارم همین امروز برم.",
    "پس پروازم رو به زمانی توی هفته ی آینده تغییر بده.",
    "گزینه ی موجود بعدی عالی هست.",
    "در مورد اسکان و حمل و نقل چطور؟",
    "بله، فکر می کنم برای اقامت یک هفته ای خود (7 روز) یک هتل مقرون به صرفه می خواهم. و من می خواهم یک ماشین اجاره کنم.",
    "می تونید هتلی که پیشنهاد کردید رو برام رزرو کنید؟ به نظر خوب میاد.",
    "بله، ادامه دهید و هر چیزی را که هزینه متوسطی دارد و در دسترس است رزرو کنید.",
    "حالا برای ماشین، گزینه های من چیست؟",
    "عالیه ممنون، بیا ارزون ترین رو انتخاب کن و 7 روز برام رزروش کن",
    "خب حالا چه توصیه هایی برای گشت و گذار دارید؟",
    "آیا اینها در دسترس هستند زمانی که من اونجام؟",
    "جذابه، من موزه ها رو دوست دارم. کجا ها میتونم برم؟ ",
    "باشه عالیه، یکی رو بردار و برای دومین روز اقامت من اونجا برام رزروش کن.",
    ]

agent = CustomerSupportAgent(model_name='gpt-3.5-turbo-0125')

for question in questions:
    agent.run(question, config)
# Out:
# ================================ Human Message =================================
#
# سلام، پرواز من چه زمانی است؟
# ================================== Ai Message ==================================
#
# سلام. پرواز شما برای فرودگاه BSL (فرودگاه بازل-مولوز) برنامه ریزی شده است. تاریخ و زمان حرکت برنامه ریزی شده برای پرواز LX0112 در تاریخ 30 آوریل 2024 ساعت 12:09 بعد از ظهر و زمان فرود برنامه ریزی شده ساعت 1:39 بعد از ظهر می‌باشد.
# ================================ Human Message =================================
#
# آیا اجازه دارم پروازم رو به زمانی زودتر موکول کنم؟ من دوست دارم همین امروز برم.
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_policy (call_PZFLo8Yszw9MIjaLScR5gAYU)
#  Call ID: call_PZFLo8Yszw9MIjaLScR5gAYU
#   Args:
#     query: Can I reschedule my flight to an earlier time?
# ================================= Tool Message =================================
# Name: lookup_policy
#
#
# ## شرایط و ضوابط خرید اینترنتی بلیط هواپیما
# عملیات خرید بلیط در وب‌سایت علی‌بابا مشمول مجموعه‌ی قوانین و مقررات تجارت الکترونیکی بوده و هرگونه تخلف تحت پیگرد قانونی قرار خواهد گرفت. خریدار ضمن خرید اینترنتی بلیط، متعهد می‌شود که از کلیه‌ی قوانین و مقررات خرید بلیط آگاهی کامل دارد.
# طبق مقررات سازمان هواپیمایی کشوری، مسئولیت کنسلی، تاخیر یا تعجیل در زمان انجام پرواز، بر عهده‌ی شرکت هواپیمایی برگزار کننده‌ی پرواز است وعلی بابا مسئولیتی در این خصوص نخواهد داشت.
# هنگام ثبت‌نام و رزرو بلیط، اطلاعات اساسی مسافر همچون نام و نام خانوادگی، مسیر پرواز، ساعت پرواز، تاریخ سفر، باید به صورت صحیح وارد گردد. بطور مثال نام مسافر باید به صورت صحیح با حروف انگلیسی وارد شود. امکان اصلاح نام مسافر پس از خرید نهایی بلیط وجود نداشته وعلی‌بابا، هیچ‌گونه مسئولیتی در قبال اطلاعاتی که به اشتباه وارد شده‌اند بر عهده ندارد و برای اصلاح اطلاعات، مسافر می‌بایست بلیط را کنسل و مجدداً خریداری کند.
# اعلام تغییرات پرواز و یا نهایی شدن سفارش در پرواز های داخلی از طریق اس ام اس و در پروازهای خارجی از طریق ایمیل و اس ام اس و بنا به ضرورت از طریق تلگرام به مسافر اعلام می شود لذا ورود تلفن معتبر و در دسترس الزامی است و در غیر این صورت مسئولیت نرسیدن پیام ها به عهده مسافر است.
# لطفا پس از اتمام فرآیند خرید به دانلود بلیط ، ارسال اس ام اس و گرفتن ایمیل توجه نمایید و پیش از اطمینان از صدور بلیط از خرید مجدد جلوگیری نمایید .
# بلیط خریداری شده، متعلق به مسافری است که مشخصاتش در سیستم وارد شده است و غیر قابل انتقال  ... (truncated)
# ================================== Ai Message ==================================
#
# شرکت هواپیمایی مسئول تعیین و تغییر زمان پرواز است. بنابراین، برای تغییر زمان پرواز خود به زودی‌تر، باید مستقیماً با شرکت هواپیمایی مربوطه تماس بگیرید و از امکان این تغییر استفاده کنید. لطفاً با شماره تماس یا آدرس ایمیل شرکت هواپیمایی تماس بگیرید و درخواست خود را ارسال کنید.
# ================================ Human Message =================================
#
# پس پروازم رو به زمانی توی هفته ی آینده تغییر بده.
# ================================== Ai Message ==================================
# Tool Calls:
#   ToFlightBookingAssistant (call_sK4ak2XXLuzNwtkVYiEYtKbI)
#  Call ID: call_sK4ak2XXLuzNwtkVYiEYtKbI
#   Args:
#     request: Change my flight to a time in the upcoming week.
# Currently in:  update_flight
# ================================= Tool Message =================================
#
# The assistant is now the Flight Updates & Booking Assistant. Reflect on the above conversation between the host assistant and the user. The user's intent is unsatisfied. Use the provided tools to assist the user. Remember, you are Flight Updates & Booking Assistant, and the booking, update, other other action is not complete until after you have successfully invoked the appropriate tool. If the user changes their mind or needs help for other tasks, call the CompleteOrEscalate function to let the primary host assistant take control. Do not mention who you are - just act as the proxy for the assistant.
# Currently in:  update_flight
# ================================== Ai Message ==================================
# Tool Calls:
#   search_flights (call_KxKrT1zXGn2htGPbXOVLWPtj)
#  Call ID: call_KxKrT1zXGn2htGPbXOVLWPtj
#   Args:
#     departure_airport: CDG
#     arrival_airport: BSL
#     start_time: 2024-05-25
#     end_time: 2024-05-31
#     limit: 5
# Currently in:  update_flight
# ================================= Tool Message =================================
# Name: search_flights
#
# [{"flight_id": 19237, "flight_no": "LX0112", "scheduled_departure": "2024-05-26 12:09:03.561731-04:00", "scheduled_arrival": "2024-05-26 13:39:03.561731-04:00", "departure_airport": "CDG", "arrival_airport": "BSL", "status": "Scheduled", "aircraft_code": "SU9", "actual_departure": null, "actual_arrival": null}, {"flight_id": 19253, "flight_no": "LX0112", "scheduled_departure": "2024-05-25 12:09:03.561731-04:00", "scheduled_arrival": "2024-05-25 13:39:03.561731-04:00", "departure_airport": "CDG", "arrival_airport": "BSL", "status": "Scheduled", "aircraft_code": "SU9", "actual_departure": null, "actual_arrival": null}, {"flight_id": 19256, "flight_no": "LX0112", "scheduled_departure": "2024-05-28 12:09:03.561731-04:00", "scheduled_arrival": "2024-05-28 13:39:03.561731-04:00", "departure_airport": "CDG", "arrival_airport": "BSL", "status": "Scheduled", "aircraft_code": "SU9", "actual_departure": null, "actual_arrival": null}, {"flight_id": 19270, "flight_no": "LX0112", "scheduled_departure": "2024-05-27 12:09:03.561731-04:00", "scheduled_arrival": "2024-05-27 13:39:03.561731-04:00", "departure_airport": "CDG", "arrival_airport": "BSL", "status": "Scheduled", "aircraft_code": "SU9", "actual_departure": null, "actual_arrival": null}, {"flight_id": 19274, "flight_no": "LX0112", "scheduled_departure": "2024-05-30 12:09:03.561731-04:00", "scheduled_arrival": "2024-05-30 13:3 ... (truncated)
# Currently in:  update_flight
# ================================== Ai Message ==================================
#
# پرواز جدید شما با شماره پرواز LX0112 برای تاریخ 25 مه 2024 ساعت 12:09 بعد از ظهر برنامه ریزی شده است. آیا مایلید این پرواز را برای شما رزرو کنم؟
# Currently in:  update_flight
# ================================ Human Message =================================
#
# گزینه ی موجود بعدی عالی هست.
# Currently in:  update_flight
# Currently in:  update_flight
# ================================== Ai Message ==================================
# Tool Calls:
#   update_ticket_to_new_flight (call_cHJFTgPkuVJVIeTWR13tJaes)
#  Call ID: call_cHJFTgPkuVJVIeTWR13tJaes
#   Args:
#     ticket_no: 7240005432906569
#     new_flight_id: 19253
# Currently in:  update_flight
# ================================ Human Message =================================
#
# در مورد اسکان و حمل و نقل چطور؟
# Currently in:  update_flight
# Currently in:  update_flight
# ================================== Ai Message ==================================
# Tool Calls:
#   CompleteOrEscalate (call_sA63fceRlgIASVMIcAJKnSjO)
#  Call ID: call_sA63fceRlgIASVMIcAJKnSjO
#   Args:
#     cancel: True
#     reason: User inquiring about accommodation and transportation.
# ================================= Tool Message =================================
#
# Resuming dialog with the host assistant. Please reflect on the past conversation and assist the user as needed.
# ================================== Ai Message ==================================
#
# بله حتما. برای رزرو هتل و اجاره خودرو، لطفا اطلاعات مکان و تاریخ مورد نظر خود را ارسال کنید تا بتوانم رزروهای لازم را برای شما انجام دهم.
# Tool Calls:
#   multi_tool_use.parallel (call_xDik2fYA1K1yXRpvj83Bv9rR)
#  Call ID: call_xDik2fYA1K1yXRpvj83Bv9rR
#   Args:
#     tool_uses: [{'recipient_name': 'functions.ToHotelBookingAssistant', 'parameters': {'location': 'مقصد شما', 'checkin_date': 'تاریخ ورود', 'checkout_date': 'تاریخ خروج', 'request': 'درخواست خاصی از هتل'}}, {'recipient_name': 'functions.ToBookCarRental', 'parameters': {'location': 'مقصد شما', 'start_date': 'تاریخ شروع', 'end_date': 'تاریخ پایان', 'request': 'درخواست خاص از اجاره خودرو'}}]
# ================================= Tool Message =================================
#
# Error: KeyError('multi_tool_use.parallel')
#  please fix your mistakes.
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[1], line 43
#      40 agent = CustomerSupportAgent(model_name='gpt-3.5-turbo-0125')
#      42 for question in questions:
# ---> 43     agent.run(question, config)
#
# File /mnt/d/work/GenAI/customer-support/src/agent.py:160, in CustomerSupportAgent.run(self, question, config)
#     156 def run(self, question, config):
#     157     events = self.graph.stream(
#     158         {"messages": ("user", question)}, config, stream_mode="values"
#     159     )
# --> 160     self.logger.log(events)
#     162     snapshot = self.graph.get_state(config)
#     163     while snapshot.next:
#     164         # We have an interrupt! The agent is
#     165         # trying to use a tool.
#     166         # The user can approve or deny it
#
# File /mnt/d/work/GenAI/customer-support/src/logger.py:6, in Logger.log(self, events)
#       5 def log(self, events):
# ----> 6     for event in events:
#       7         self.log_event(event)
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/langgraph/pregel/__init__.py:771, in Pregel.stream(self, input, config, stream_mode, output_keys, input_keys, interrupt_before, interrupt_after, debug)
#     764 done, inflight = concurrent.futures.wait(
#     765     futures,
#     766     return_when=concurrent.futures.FIRST_EXCEPTION,
#     767     timeout=self.step_timeout,
#     768 )
#     770 # panic on failure or timeout
# --> 771 _panic_or_proceed(done, inflight, step)
#     773 # combine pending writes from all tasks
#     774 pending_writes = deque[tuple[str, Any]]()
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/langgraph/pregel/__init__.py:1263, in _panic_or_proceed(done, inflight, step)
#    1261             inflight.pop().cancel()
#    1262         # raise the exception
# -> 1263         raise exc
#    1264         # TODO this is where retry of an entire step would happen
#    1266 if inflight:
#    1267     # if we got here means we timed out
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/langchain_core/runnables/base.py:2499, in RunnableSequence.invoke(self, input, config)
#    2497 try:
#    2498     for i, step in enumerate(self.steps):
# -> 2499         input = step.invoke(
#    2500             input,
#    2501             # mark each step as a child run
#    2502             patch_config(
#    2503                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2504             ),
#    2505         )
#    2506 # finish the root run
#    2507 except BaseException as e:
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/langgraph/utils.py:88, in RunnableCallable.invoke(self, input, config)
#      82     context.run(var_child_runnable_config.set, config)
#      83     kwargs = (
#      84         {**self.kwargs, "config": config}
#      85         if accepts_config(self.func)
#      86         else self.kwargs
#      87     )
# ---> 88     ret = context.run(self.func, input, **kwargs)
#      89 if isinstance(ret, Runnable) and self.recurse:
#      90     return ret.invoke(input, config)
#
# File /mnt/d/work/GenAI/customer-support/src/models/assistant.py:11, in Assistant.__call__(self, state, config)
#       9 def __call__(self, state: State, config: RunnableConfig):
#      10     while True:
# ---> 11         result = self.runnable.invoke(state)
#      13         if not result.tool_calls and (
#      14             not result.content
#      15             or isinstance(result.content, list)
#      16             and not result.content[0].get("text")
#      17         ):
#      18             messages = state["messages"] + [("user", "Respond with a real output.")]
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/langchain_core/runnables/base.py:2499, in RunnableSequence.invoke(self, input, config)
#    2497 try:
#    2498     for i, step in enumerate(self.steps):
# -> 2499         input = step.invoke(
#    2500             input,
#    2501             # mark each step as a child run
#    2502             patch_config(
#    2503                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2504             ),
#    2505         )
#    2506 # finish the root run
#    2507 except BaseException as e:
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/langchain_core/runnables/base.py:4525, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4519 def invoke(
#    4520     self,
#    4521     input: Input,
#    4522     config: Optional[RunnableConfig] = None,
#    4523     **kwargs: Optional[Any],
#    4524 ) -> Output:
# -> 4525     return self.bound.invoke(
#    4526         input,
#    4527         self._merge_configs(config),
#    4528         **{**self.kwargs, **kwargs},
#    4529     )
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:158, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     147 def invoke(
#     148     self,
#     149     input: LanguageModelInput,
#    (...)
#     153     **kwargs: Any,
#     154 ) -> BaseMessage:
#     155     config = ensure_config(config)
#     156     return cast(
#     157         ChatGeneration,
# --> 158         self.generate_prompt(
#     159             [self._convert_input(input)],
#     160             stop=stop,
#     161             callbacks=config.get("callbacks"),
#     162             tags=config.get("tags"),
#     163             metadata=config.get("metadata"),
#     164             run_name=config.get("run_name"),
#     165             run_id=config.pop("run_id", None),
#     166             **kwargs,
#     167         ).generations[0][0],
#     168     ).message
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:560, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     552 def generate_prompt(
#     553     self,
#     554     prompts: List[PromptValue],
#    (...)
#     557     **kwargs: Any,
#     558 ) -> LLMResult:
#     559     prompt_messages = [p.to_messages() for p in prompts]
# --> 560     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:421, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     419         if run_managers:
#     420             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 421         raise e
#     422 flattened_outputs = [
#     423     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     424     for res in results
#     425 ]
#     426 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:411, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     408 for i, m in enumerate(messages):
#     409     try:
#     410         results.append(
# --> 411             self._generate_with_cache(
#     412                 m,
#     413                 stop=stop,
#     414                 run_manager=run_managers[i] if run_managers else None,
#     415                 **kwargs,
#     416             )
#     417         )
#     418     except BaseException as e:
#     419         if run_managers:
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:632, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     630 else:
#     631     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 632         result = self._generate(
#     633             messages, stop=stop, run_manager=run_manager, **kwargs
#     634         )
#     635     else:
#     636         result = self._generate(messages, stop=stop, **kwargs)
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:522, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     520 message_dicts, params = self._create_message_dicts(messages, stop)
#     521 params = {**params, **kwargs}
# --> 522 response = self.client.create(messages=message_dicts, **params)
#     523 return self._create_chat_result(response)
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/openai/resources/chat/completions.py:590, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     558 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     559 def create(
#     560     self,
#    (...)
#     588     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     589 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 590     return self._post(
#     591         "/chat/completions",
#     592         body=maybe_transform(
#     593             {
#     594                 "messages": messages,
#     595                 "model": model,
#     596                 "frequency_penalty": frequency_penalty,
#     597                 "function_call": function_call,
#     598                 "functions": functions,
#     599                 "logit_bias": logit_bias,
#     600                 "logprobs": logprobs,
#     601                 "max_tokens": max_tokens,
#     602                 "n": n,
#     603                 "presence_penalty": presence_penalty,
#     604                 "response_format": response_format,
#     605                 "seed": seed,
#     606                 "stop": stop,
#     607                 "stream": stream,
#     608                 "stream_options": stream_options,
#     609                 "temperature": temperature,
#     610                 "tool_choice": tool_choice,
#     611                 "tools": tools,
#     612                 "top_logprobs": top_logprobs,
#     613                 "top_p": top_p,
#     614                 "user": user,
#     615             },
#     616             completion_create_params.CompletionCreateParams,
#     617         ),
#     618         options=make_request_options(
#     619             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     620         ),
#     621         cast_to=ChatCompletion,
#     622         stream=stream or False,
#     623         stream_cls=Stream[ChatCompletionChunk],
#     624     )
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/openai/_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/openai/_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File /mnt/d/work/GenAI/customer-support/env/lib/python3.10/site-packages/openai/_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1017         err.response.read()
#    1019     log.debug("Re-raising status error")
# -> 1020     raise self._make_status_error_from_response(err.response) from None
#    1022 return self._process_response(
#    1023     cast_to=cast_to,
#    1024     options=options,
#    (...)
#    1027     stream_cls=stream_cls,
#    1028 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "Invalid 'messages[20].tool_calls[0].function.name': string does not match pattern. Expected a string that matches the pattern '^[a-zA-Z0-9_-]+$'.", 'type': 'invalid_request_error', 'param': 'messages[20].tool_calls[0].function.name', 'code': 'invalid_value'}}

# %%
import shutil
import uuid

from src.agent import CustomerSupportAgent


db = "travel2.sqlite"
backup_file = "travel2.backup.sqlite"

shutil.copy(backup_file, db)
thread_id = str(uuid.uuid4())

config = {
    "configurable": {
        # The passenger_id is used in our flight tools to
        # fetch the user's flight information
        "passenger_id": "3442 587242",
        # Checkpoints are accessed by thread_id
        "thread_id": thread_id,
}
}

questions = [
    "سلام، پرواز من چه زمانی است؟",
    "آیا اجازه دارم پروازم رو به زمانی زودتر موکول کنم؟ من دوست دارم همین امروز برم.",
    "پس پروازم رو به زمانی توی هفته ی آینده تغییر بده.",
    "گزینه ی موجود بعدی عالی هست.",
    "در مورد اسکان و حمل و نقل چطور؟",
    "بله، فکر می کنم برای اقامت یک هفته ای خود (7 روز) یک هتل مقرون به صرفه می خواهم. و من می خواهم یک ماشین اجاره کنم.",
    "می تونید هتلی که پیشنهاد کردید رو برام رزرو کنید؟ به نظر خوب میاد.",
    "بله، ادامه دهید و هر چیزی را که هزینه متوسطی دارد و در دسترس است رزرو کنید.",
    "حالا برای ماشین، گزینه های من چیست؟",
    "عالیه ممنون، بیا ارزون ترین رو انتخاب کن و 7 روز برام رزروش کن",
    "خب حالا چه پیشنهادی برای گشت و گذار دارید؟",
    "آیا اینها در دسترس هستند زمانی که من اونجام؟",
    "جذابه، من موزه ها رو دوست دارم. کجا ها میتونم برم؟ ",
    "باشه عالیه، یکی رو بردار و برای دومین روز اقامت من اونجا برام رزروش کن.",
    ]

agent = CustomerSupportAgent(model_name='gpt-3.5-turbo-0125')

for question in questions:
    agent.run(question, config)
# Out:
# ================================ Human Message =================================
#
# سلام، پرواز من چه زمانی است؟
# ================================== Ai Message ==================================
#
# برای شما پروازی به مقصد فرودگاه BSL از فرودگاه CDG در تاریخ 30 آوریل 2024 ساعت 12:09 دقیقه برنامه‌ریزی شده است. مقرر است که ساعت 13:39 دقیقه به مقصد برسید.
# ================================ Human Message =================================
#
# آیا اجازه دارم پروازم رو به زمانی زودتر موکول کنم؟ من دوست دارم همین امروز برم.
# ================================== Ai Message ==================================
# Tool Calls:
#   lookup_policy (call_WAX7uUxpONUsP6lWe8nruv14)
#  Call ID: call_WAX7uUxpONUsP6lWe8nruv14
#   Args:
#     query: Can I reschedule my flight to an earlier time?
# ================================= Tool Message =================================
# Name: lookup_policy
#
#
# ## شرایط و ضوابط خرید اینترنتی بلیط هواپیما
# عملیات خرید بلیط در وب‌سایت علی‌بابا مشمول مجموعه‌ی قوانین و مقررات تجارت الکترونیکی بوده و هرگونه تخلف تحت پیگرد قانونی قرار خواهد گرفت. خریدار ضمن خرید اینترنتی بلیط، متعهد می‌شود که از کلیه‌ی قوانین و مقررات خرید بلیط آگاهی کامل دارد.
# طبق مقررات سازمان هواپیمایی کشوری، مسئولیت کنسلی، تاخیر یا تعجیل در زمان انجام پرواز، بر عهده‌ی شرکت هواپیمایی برگزار کننده‌ی پرواز است وعلی بابا مسئولیتی در این خصوص نخواهد داشت.
# هنگام ثبت‌نام و رزرو بلیط، اطلاعات اساسی مسافر همچون نام و نام خانوادگی، مسیر پرواز، ساعت پرواز، تاریخ سفر، باید به صورت صحیح وارد گردد. بطور مثال نام مسافر باید به صورت صحیح با حروف انگلیسی وارد شود. امکان اصلاح نام مسافر پس از خرید نهایی بلیط وجود نداشته وعلی‌بابا، هیچ‌گونه مسئولیتی در قبال اطلاعاتی که به اشتباه وارد شده‌اند بر عهده ندارد و برای اصلاح اطلاعات، مسافر می‌بایست بلیط را کنسل و مجدداً خریداری کند.
# اعلام تغییرات پرواز و یا نهایی شدن سفارش در پرواز های داخلی از طریق اس ام اس و در پروازهای خارجی از طریق ایمیل و اس ام اس و بنا به ضرورت از طریق تلگرام به مسافر اعلام می شود لذا ورود تلفن معتبر و در دسترس الزامی است و در غیر این صورت مسئولیت نرسیدن پیام ها به عهده مسافر است.
# لطفا پس از اتمام فرآیند خرید به دانلود بلیط ، ارسال اس ام اس و گرفتن ایمیل توجه نمایید و پیش از اطمینان از صدور بلیط از خرید مجدد جلوگیری نمایید .
# بلیط خریداری شده، متعلق به مسافری است که مشخصاتش در سیستم وارد شده است و غیر قابل انتقال  ... (truncated)
# ================================== Ai Message ==================================
#
# بله، می‌توانید پرواز خود را به زمانی زودتر موکول کنید. اما لطفاً توجه داشته باشید که ممکن است برای این تغییرات هزینه‌های اضافی و جریمه‌های کنسلی وجود داشته باشد. برای اطلاعات دقیق‌تر و انجام این تغییرات، می‌توانید با مسئولین شرکت هواپیمایی تماس بگیرید.
# ================================ Human Message =================================
#
# پس پروازم رو به زمانی توی هفته ی آینده تغییر بده.
# ================================== Ai Message ==================================
# Tool Calls:
#   ToFlightBookingAssistant (call_T72pA5qUluvfetF4U7L6lqhr)
#  Call ID: call_T72pA5qUluvfetF4U7L6lqhr
#   Args:
#     request: Change my flight to a time next week.
# Currently in:  update_flight
# ================================= Tool Message =================================
#
# The assistant is now the Flight Updates & Booking Assistant. Reflect on the above conversation between the host assistant and the user. The user's intent is unsatisfied. Use the provided tools to assist the user. Remember, you are Flight Updates & Booking Assistant, and the booking, update, other other action is not complete until after you have successfully invoked the appropriate tool. If the user changes their mind or needs help for other tasks, call the CompleteOrEscalate function to let the primary host assistant take control. Do not mention who you are - just act as the proxy for the assistant.
# Currently in:  update_flight
# ================================== Ai Message ==================================
# Tool Calls:
#   search_flights (call_gRWJX6vCARTBsI2k3HomNNmr)
#  Call ID: call_gRWJX6vCARTBsI2k3HomNNmr
#   Args:
#     limit: 5
#     start_time: 2024-05-25
#     end_time: 2024-05-31
# Currently in:  update_flight
# ================================= Tool Message =================================
# Name: search_flights
#
# [{"flight_id": 1185, "flight_no": "QR0051", "scheduled_departure": "2024-05-26 03:59:03.561731-04:00", "scheduled_arrival": "2024-05-26 09:04:03.561731-04:00", "departure_airport": "BSL", "arrival_airport": "BKK", "status": "Scheduled", "aircraft_code": "319", "actual_departure": null, "actual_arrival": null}, {"flight_id": 5502, "flight_no": "LX0136", "scheduled_departure": "2024-05-28 03:59:03.561731-04:00", "scheduled_arrival": "2024-05-28 05:29:03.561731-04:00", "departure_airport": "OSL", "arrival_airport": "PRG", "status": "Scheduled", "aircraft_code": "763", "actual_departure": null, "actual_arrival": null}, {"flight_id": 7784, "flight_no": "QF0028", "scheduled_departure": "2024-05-26 09:09:03.561731-04:00", "scheduled_arrival": "2024-05-26 11:39:03.561731-04:00", "departure_airport": "OSL", "arrival_airport": "EDI", "status": "Scheduled", "aircraft_code": "CR2", "actual_departure": null, "actual_arrival": null}, {"flight_id": 11847, "flight_no": "CA0065", "scheduled_departure": "2024-05-28 04:24:03.561731-04:00", "scheduled_arrival": "2024-05-28 09:04:03.561731-04:00", "departure_airport": "GVA", "arrival_airport": "DEN", "status": "Scheduled", "aircraft_code": "319", "actual_departure": null, "actual_arrival": null}, {"flight_id": 17173, "flight_no": "IB0005", "scheduled_departure": "2024-05-30 06:34:03.561731-04:00", "scheduled_arrival": "2024-05-30 08:54:0 ... (truncated)
# Currently in:  update_flight
# ================================== Ai Message ==================================
#
# من تعدادی پرواز در هفته آینده برای شما پیدا کردم:
#
# 1. پرواز شماره QR0051 از فرودگاه BSL به فرودگاه BKK در تاریخ 26 مه 2024 برنامه‌ریزی شده است.
# 2. پرواز شماره LX0136 از فرودگاه OSL به فرودگاه PRG در تاریخ 28 مه 2024 برنامه‌ریزی شده است.
# 3. پرواز شماره QF0028 از فرودگاه OSL به فرودگاه EDI در تاریخ 26 مه 2024 برنامه‌ریزی شده است.
# 4. پرواز شماره CA0065 از فرودگاه GVA به فرودگاه DEN در تاریخ 28 مه 2024 برنامه‌ریزی شده است.
# 5. پرواز شماره IB0005 از فرودگاه NBO به فرودگاه IAH در تاریخ 30 مه 2024 لغو شده است.
#
# لطفاً برای تغییر پرواز خود، پرواز مورد نظر خود را انتخاب کرده و اطلاعات بیشتری از مسئولین شرکت هواپیمایی دریافت کنید.
# Currently in:  update_flight
# ================================ Human Message =================================
#
# گزینه ی موجود بعدی عالی هست.
# Currently in:  update_flight
# Currently in:  update_flight
# ================================== Ai Message ==================================
# Tool Calls:
#   update_ticket_to_new_flight (call_M6xNRZ9iayw1A6SfzyDReWJv)
#  Call ID: call_M6xNRZ9iayw1A6SfzyDReWJv
#   Args:
#     ticket_no: 7240005432906569
#     new_flight_id: 5502
# Currently in:  update_flight
# ================================ Human Message =================================
#
# در مورد اسکان و حمل و نقل چطور؟
# Currently in:  update_flight
# Currently in:  update_flight
# ================================== Ai Message ==================================
#
# متاسفانه من اطلاعات دقیق در مورد اسکان و حمل و نقل را ندارم. لطفاً با مسئولین شرکت هواپیمایی یا مراکز مربوطه تماس بگیرید تا اطلاعات لازم را از آن‌ها دریافت کنید. در صورت نیاز به کمک بیشتر یا سوال دیگری، خوشحال می‌شوم کمک کنم.
# Currently in:  update_flight
# ================================ Human Message =================================
#
# بله، فکر می کنم برای اقامت یک هفته ای خود (7 روز) یک هتل مقرون به صرفه می خواهم. و من می خواهم یک ماشین اجاره کنم.
# Currently in:  update_flight
# Currently in:  update_flight
# ================================== Ai Message ==================================
# Tool Calls:
#   CompleteOrEscalate (call_IBiLqH1R0XhaUaVYJCT6WLTd)
#  Call ID: call_IBiLqH1R0XhaUaVYJCT6WLTd
#   Args:
#     reason: User needs assistance with hotel booking and car rental for a one-week stay.
# ================================= Tool Message =================================
#
# Resuming dialog with the host assistant. Please reflect on the past conversation and assist the user as needed.
# ================================== Ai Message ==================================
# Tool Calls:
#   ToHotelBookingAssistant (call_QEYm8jM0YkZu5aW1BnrZDdAC)
#  Call ID: call_QEYm8jM0YkZu5aW1BnrZDdAC
#   Args:
#     location: مقصد اقامت
#     checkin_date: 2024-05-26
#     checkout_date: 2024-06-02
#     request: یافتن یک هتل مقرون به صرفه برای هفته آینده.
# Currently in:  book_hotel
# ================================= Tool Message =================================
#
# The assistant is now the Hotel Booking Assistant. Reflect on the above conversation between the host assistant and the user. The user's intent is unsatisfied. Use the provided tools to assist the user. Remember, you are Hotel Booking Assistant, and the booking, update, other other action is not complete until after you have successfully invoked the appropriate tool. If the user changes their mind or needs help for other tasks, call the CompleteOrEscalate function to let the primary host assistant take control. Do not mention who you are - just act as the proxy for the assistant.
# Currently in:  book_hotel
# ================================== Ai Message ==================================
# Tool Calls:
#   search_hotels (call_36rb0ImCMkLv3SaFADlnRTHO)
#  Call ID: call_36rb0ImCMkLv3SaFADlnRTHO
#   Args:
#     checkin_date: 2024-05-26
#     checkout_date: 2024-06-02
# Currently in:  book_hotel
# ================================= Tool Message =================================
# Name: search_hotels
#
# [{"id": 1, "name": "Hilton Basel", "location": "Basel", "price_tier": "Luxury", "checkin_date": "2024-04-22", "checkout_date": "2024-04-20", "booked": 0}, {"id": 2, "name": "Marriott Zurich", "location": "Zurich", "price_tier": "Upscale", "checkin_date": "2024-04-14", "checkout_date": "2024-04-21", "booked": 0}, {"id": 3, "name": "Hyatt Regency Basel", "location": "Basel", "price_tier": "Upper Upscale", "checkin_date": "2024-04-02", "checkout_date": "2024-04-20", "booked": 0}, {"id": 4, "name": "Radisson Blu Lucerne", "location": "Lucerne", "price_tier": "Midscale", "checkin_date": "2024-04-24", "checkout_date": "2024-04-05", "booked": 0}, {"id": 5, "name": "Best Western Bern", "location": "Bern", "price_tier": "Upper Midscale", "checkin_date": "2024-04-23", "checkout_date": "2024-04-01", "booked": 0}, {"id": 6, "name": "InterContinental Geneva", "location": "Geneva", "price_tier": "Luxury", "checkin_date": "2024-04-23", "checkout_date": "2024-04-28", "booked": 0}, {"id": 7, "name": "Sheraton Zurich", "location": "Zurich", "price_tier": "Upper Upscale", "checkin_date": "2024-04-27", "checkout_date": "2024-04-02", "booked": 0}, {"id": 8, "name": "Holiday Inn Basel", "location": "Basel", "price_tier": "Upper Midscale", "checkin_date": "2024-04-24", "checkout_date": "2024-04-09", "booked": 0}, {"id": 9, "name": "Courtyard Zurich", "location": "Zurich", "price_tier": "Ups ... (truncated)
# Currently in:  book_hotel
# ================================== Ai Message ==================================
#
# من چند گزینه برای هتل‌های مقرون به صرفه برای اقامت شما در هفته آینده پیدا کردم:
#
# 1. هتل Hilton Basel - محل: Basel - رده قیمت: لوکس
# 2. هتل Radisson Blu Lucerne - محل: Lucerne - رده قیمت: میانه
# 3. هتل Best Western Bern - محل: Bern - رده قیمت: میانه
# 4. هتل Comfort Inn Bern - محل: Bern - رده قیمت: میانه
#
# لطفاً هتل مورد نظر خود را انتخاب کرده و برای رزرو و اطلاعات بیشتر با مسئولین هتل تماس بگیرید. همچنین برای اجاره خودرو، می‌توانید با شرکت‌های اجاره خودرو محلی تماس بگیرید و نیاز‌های خود را مطرح کنید. در صورت نیاز به کمک بیشتر، خوشحال می‌شوم کمک کنم.
# Currently in:  book_hotel
# ================================ Human Message =================================
#
# می تونید هتلی که پیشنهاد کردید رو برام رزرو کنید؟ به نظر خوب میاد.
# Currently in:  book_hotel
# Currently in:  book_hotel
# ================================== Ai Message ==================================
# Tool Calls:
#   book_hotel (call_eTEpDBKOmGbQjJFOQjCw2hg0)
#  Call ID: call_eTEpDBKOmGbQjJFOQjCw2hg0
#   Args:
#     hotel_id: 4
# Currently in:  book_hotel
# ================================ Human Message =================================
#
# بله، ادامه دهید و هر چیزی را که هزینه متوسطی دارد و در دسترس است رزرو کنید.
# Currently in:  book_hotel
# Currently in:  book_hotel
# ================================== Ai Message ==================================
# Tool Calls:
#   search_hotels (call_x3l9tyidt0zphMO9kKRg2T4z)
#  Call ID: call_x3l9tyidt0zphMO9kKRg2T4z
#   Args:
#     price_tier: Midscale
#     checkin_date: 2024-05-26
#     checkout_date: 2024-06-02
# Currently in:  book_hotel
# ================================= Tool Message =================================
# Name: search_hotels
#
# [{"id": 1, "name": "Hilton Basel", "location": "Basel", "price_tier": "Luxury", "checkin_date": "2024-04-22", "checkout_date": "2024-04-20", "booked": 0}, {"id": 2, "name": "Marriott Zurich", "location": "Zurich", "price_tier": "Upscale", "checkin_date": "2024-04-14", "checkout_date": "2024-04-21", "booked": 0}, {"id": 3, "name": "Hyatt Regency Basel", "location": "Basel", "price_tier": "Upper Upscale", "checkin_date": "2024-04-02", "checkout_date": "2024-04-20", "booked": 0}, {"id": 4, "name": "Radisson Blu Lucerne", "location": "Lucerne", "price_tier": "Midscale", "checkin_date": "2024-04-24", "checkout_date": "2024-04-05", "booked": 1}, {"id": 5, "name": "Best Western Bern", "location": "Bern", "price_tier": "Upper Midscale", "checkin_date": "2024-04-23", "checkout_date": "2024-04-01", "booked": 0}, {"id": 6, "name": "InterContinental Geneva", "location": "Geneva", "price_tier": "Luxury", "checkin_date": "2024-04-23", "checkout_date": "2024-04-28", "booked": 0}, {"id": 7, "name": "Sheraton Zurich", "location": "Zurich", "price_tier": "Upper Upscale", "checkin_date": "2024-04-27", "checkout_date": "2024-04-02", "booked": 0}, {"id": 8, "name": "Holiday Inn Basel", "location": "Basel", "price_tier": "Upper Midscale", "checkin_date": "2024-04-24", "checkout_date": "2024-04-09", "booked": 0}, {"id": 9, "name": "Courtyard Zurich", "location": "Zurich", "price_tier": "Ups ... (truncated)
# Currently in:  book_hotel
# ================================== Ai Message ==================================
# Tool Calls:
#   book_hotel (call_p0N7QyL27S8qkZH5drOatv1G)
#  Call ID: call_p0N7QyL27S8qkZH5drOatv1G
#   Args:
#     hotel_id: 10
# Currently in:  book_hotel
# ================================ Human Message =================================
#
# حالا برای ماشین، گزینه های من چیست؟
# Currently in:  book_hotel
# Currently in:  book_hotel
# ================================== Ai Message ==================================
# Tool Calls:
#   CompleteOrEscalate (call_SNExTlhlI2zOU6r7cXAEAnYG)
#  Call ID: call_SNExTlhlI2zOU6r7cXAEAnYG
#   Args:
#     reason: User needs assistance with car rental.
# ================================= Tool Message =================================
#
# Resuming dialog with the host assistant. Please reflect on the past conversation and assist the user as needed.
# ================================== Ai Message ==================================
# Tool Calls:
#   ToBookCarRental (call_2Cp4OFTjdC68l8kP6FNZ3Ty0)
#  Call ID: call_2Cp4OFTjdC68l8kP6FNZ3Ty0
#   Args:
#     location: مقصد
#     start_date: 2024-05-26
#     end_date: 2024-06-02
#     request: یافتن یک ماشین اجاره ای برای هفته آینده.
# Currently in:  book_car_rental
# ================================= Tool Message =================================
#
# The assistant is now the Car Rental Assistant. Reflect on the above conversation between the host assistant and the user. The user's intent is unsatisfied. Use the provided tools to assist the user. Remember, you are Car Rental Assistant, and the booking, update, other other action is not complete until after you have successfully invoked the appropriate tool. If the user changes their mind or needs help for other tasks, call the CompleteOrEscalate function to let the primary host assistant take control. Do not mention who you are - just act as the proxy for the assistant.
# Currently in:  book_car_rental
# ================================== Ai Message ==================================
# Tool Calls:
#   search_car_rentals (call_htpO5ED2YR7So4hDi2LEtn4N)
#  Call ID: call_htpO5ED2YR7So4hDi2LEtn4N
#   Args:
#     location: مقصد
#     start_date: 2024-05-26
#     end_date: 2024-06-02
# Currently in:  book_car_rental
# ================================= Tool Message =================================
# Name: search_car_rentals
#
# []
# Currently in:  book_car_rental
# ================================== Ai Message ==================================
#
# متاسفانه در حال حاضر گزینه‌ای برای اجاره ماشین در مقصد مورد نظر شما برای هفته آینده موجود نیست. آیا مایل به تغییر مقصد یا تاریخ‌های اجاره هستید؟ یا آیا می‌خواهید روند رزرو را ادامه دهید؟
# Tool Calls:
#   CompleteOrEscalate (call_EVUo7LD9WxGOfwKueWhcxach)
#  Call ID: call_EVUo7LD9WxGOfwKueWhcxach
#   Args:
#     reason: User needs to consider changing the destination or rental dates for finding available car rental options.
# ================================= Tool Message =================================
#
# Resuming dialog with the host assistant. Please reflect on the past conversation and assist the user as needed.
# ================================== Ai Message ==================================
#
# با توجه به عدم وجود گزینه‌ای برای اجاره ماشین در مقصد مورد نظر برای هفته آینده، آیا مایل هستید تاریخ‌ها یا مقصد را تغییر دهید یا نیاز دارید کمکی دیگری داشته باشید؟ من در خدمت شما هستم.
# ================================ Human Message =================================
#
# عالیه ممنون، بیا ارزون ترین رو انتخاب کن و 7 روز برام رزروش کن
# ================================== Ai Message ==================================
# Tool Calls:
#   ToBookCarRental (call_l6W4whP0auTQdINxHq5Ve95D)
#  Call ID: call_l6W4whP0auTQdINxHq5Ve95D
#   Args:
#     end_date: 2024-06-02
#     location: مقصد
#     request: یافتن ماشین اجاره‌ای ارزان قیمت برای 7 روز آینده.
#     start_date: 2024-05-26
# Currently in:  book_car_rental
# ================================= Tool Message =================================
#
# The assistant is now the Car Rental Assistant. Reflect on the above conversation between the host assistant and the user. The user's intent is unsatisfied. Use the provided tools to assist the user. Remember, you are Car Rental Assistant, and the booking, update, other other action is not complete until after you have successfully invoked the appropriate tool. If the user changes their mind or needs help for other tasks, call the CompleteOrEscalate function to let the primary host assistant take control. Do not mention who you are - just act as the proxy for the assistant.
# Currently in:  book_car_rental
# ================================== Ai Message ==================================
# Tool Calls:
#   search_car_rentals (call_S9Gjw27P8jsNHGpyKydgsQ1i)
#  Call ID: call_S9Gjw27P8jsNHGpyKydgsQ1i
#   Args:
#     start_date: 2024-05-26
#     end_date: 2024-06-02
# Currently in:  book_car_rental
# ================================= Tool Message =================================
# Name: search_car_rentals
#
# [{"id": 1, "name": "Europcar", "location": "Basel", "price_tier": "Economy", "start_date": "2024-04-14", "end_date": "2024-04-11", "booked": 0}, {"id": 2, "name": "Avis", "location": "Basel", "price_tier": "Luxury", "start_date": "2024-04-10", "end_date": "2024-04-20", "booked": 0}, {"id": 3, "name": "Hertz", "location": "Zurich", "price_tier": "Midsize", "start_date": "2024-04-10", "end_date": "2024-04-07", "booked": 0}, {"id": 4, "name": "Sixt", "location": "Bern", "price_tier": "SUV", "start_date": "2024-04-20", "end_date": "2024-04-26", "booked": 0}, {"id": 5, "name": "Budget", "location": "Lucerne", "price_tier": "Compact", "start_date": "2024-04-01", "end_date": "2024-04-19", "booked": 0}, {"id": 6, "name": "Alamo", "location": "Geneva", "price_tier": "Full-size", "start_date": "2024-04-27", "end_date": "2024-04-18", "booked": 0}, {"id": 7, "name": "Enterprise", "location": "Basel", "price_tier": "Premium", "start_date": "2024-04-22", "end_date": "2024-04-20", "booked": 0}, {"id": 8, "name": "National", "location": "Zurich", "price_tier": "Economy", "start_date": "2024-04-08", "end_date": "2024-04-21", "booked": 0}, {"id": 9, "name": "Thrifty", "location": "Basel", "price_tier": "Midsize", "start_date": "2024-04-17", "end_date": "2024-04-26", "booked": 0}, {"id": 10, "name": "Dollar", "location": "Bern", "price_tier": "Compact", "start_date": "2024-04-23",  ... (truncated)
# Currently in:  book_car_rental
# ================================== Ai Message ==================================
# Tool Calls:
#   book_car_rental (call_XRRJpUYUJFGLqkJ0DTEH1QBk)
#  Call ID: call_XRRJpUYUJFGLqkJ0DTEH1QBk
#   Args:
#     rental_id: 1
# Currently in:  book_car_rental
# ================================ Human Message =================================
#
# خب حالا چه توصیه هایی برای گشت و گذار دارید؟
# Currently in:  book_car_rental
# Currently in:  book_car_rental
# ================================== Ai Message ==================================
#
# برای گشت و گذار در مقصد خود، این توصیه‌های را در نظر بگیرید:
#
# 1. برنامه‌ریزی مسیر: قبل از شروع سفر، برنامه‌ریزی دقیقی از مسیر و جاذبه‌هایی که می‌خواهید بازدید کنید، داشته باشید.
#
# 2. اطلاع از جاذبه‌ها: اطلاعات کاملی از جاذبه‌های محلی، رستوران‌ها، موزه‌ها و فعالیت‌های تفریحی در اختیار داشته باشید.
#
# 3. امنیت: از امنیت خود و اموالتان مراقبت کنید و از جاهایی که امنیتی ندارند، دوری کنید.
#
# 4. خریدهای محلی: از فرصت خرید اقلام محلی و سوغاتی بهره ببرید.
#
# 5. آشنایی با فرهنگ محلی: با فرهنگ و تقالید محلی آشنا شوید و احترام به آنها را حفظ کنید.
#
# 6. زمانبندی مناسب: برنامه‌ریزی زمانی مناسب برای هر جاذبه و فعالیت را در نظر بگیرید تا از سفرتان لذت ببرید.
#
# 7. حفظ محیط زیست: در هنگام گشت و گذار، به حفاظت از محیط زیست توجه کنید و زباله‌های خود را به دقت دور بیندازید.
#
# 8. عکس‌های خاطره‌انگیز: لحظات خاص سفر خود را با عکس‌های زیبا ثبت کنید تا به یادگار داشته باشید.
#
# با رعایت این توصیه‌ها، امیدوارم سفر شما لذت‌بخش و به یادماندنی باشد. اگر نیاز به اطلاعات بیشتر یا راهنمایی دیگری دارید، من در خدمت شما هستم.
# Currently in:  book_car_rental
# ================================ Human Message =================================
#
# آیا اینها در دسترس هستند زمانی که من اونجام؟
# Currently in:  book_car_rental
# Currently in:  book_car_rental
# ================================== Ai Message ==================================
#
# بله، بسیاری از توصیه‌ها و راهنمایی‌هایی که ارائه دادم، می‌توانند در دسترس شما باشند هنگامی که در مقصد خود هستید. به عنوان مثال، اطلاعات در مورد جاذبه‌ها و رستوران‌ها معمولاً در دسترس اینترنتی است و شما می‌توانید قبل از سفر یا حتی در حین سفر به آنها دسترسی داشته باشید. همچنین از طریق اپلیکیشن‌های مسافرتی، می‌توانید مسیرها، زمانبندی‌ها و اطلاعات مربوط به سفر خود را مدیریت کنید. اما برای اطمینان بیشتر، می‌توانید قبل از سفر برنامه‌ریزی دقیق‌تری انجام دهید و اطلاعات مورد نیاز را در دسترس داشته باشید. در هر صورت، من همیشه در دسترس هستم تا به شما کمک کنم.
# Currently in:  book_car_rental
# ================================ Human Message =================================
#
# جذابه، من موزه ها رو دوست دارم. کجا ها میتونم برم؟
# Currently in:  book_car_rental
# Currently in:  book_car_rental
# ================================== Ai Message ==================================
#
# با لذت! در هر شهری که می‌روید، موزه‌ها معمولاً یکی از جاذبه‌های اصلی و فرهنگی آن شهر هستند. اینجا چند موزه معروف در شهرهای مختلف سوئیس را برای شما لیست می‌کنم:
#
# 1. موزه هنر معاصر و معماری (Kunsthaus Zürich) - زوریخ: این موزه یکی از بزرگترین موزه‌های هنری در اروپاست و مجموعه‌ای بی‌نظیر از اثار هنری معاصر و معماری را به نمایش می‌گذارد.
#
# 2. موزه تاریخی برن (Bern Historical Museum) - برن: این موزه یکی از قدیمی‌ترین موزه‌های سوئیس است و مجموعه‌ای از اشیاء تاریخی، هنری و فرهنگی را به نمایش می‌گذارد.
#
# 3. موزه کاپلهاوف (Kapellhaus Museum) - لوزان: این موزه معروف به مجموعه‌ای از آثار هنری از قرن 15 تا 20 از هنرمندان معروف مانند رودریگو و پیکاسو می‌باشد.
#
# 4. موزه پرادو (Prado Museum) - ژنو: این موزه معروف به مجموعه‌ای از آثار هنری از دوره‌های مختلف و هنرمندان معروف اروپایی مانند ونگوگ، مونه و دالی می‌پردازد.
#
# 5. موزه قدیمی ویترو (Vitro Museum) - بازل: این موزه به مجموعه‌ای از آثار هنری و تاریخی از دوره رنسانس تا امروز می‌پردازد و یکی از مقاصد محبوب گردشگران در شهر بازل است.
#
# اما این فقط چند نمونه از موزه‌های معروف سوئیس است. هر شهر دیگری که می‌روید هم موزه‌های جذاب و متنوعی دارد که می‌توانید به آنها سر بزنید و از دیدن اثار هنری و تاریخی لذت ببرید.
# Currently in:  book_car_rental
# ================================ Human Message =================================
#
# باشه عالیه، یکی رو بردار و برای دومین روز اقامت من اونجا برام رزروش کن.
# Currently in:  book_car_rental
# Currently in:  book_car_rental
# ================================== Ai Message ==================================
# Tool Calls:
#   CompleteOrEscalate (call_jwyLNXoxu5TXfYDSTbVkZAaB)
#  Call ID: call_jwyLNXoxu5TXfYDSTbVkZAaB
#   Args:
#     reason: User wants to book a museum visit for the second day of their stay.
# ================================= Tool Message =================================
#
# Resuming dialog with the host assistant. Please reflect on the past conversation and assist the user as needed.
# ================================== Ai Message ==================================
# Tool Calls:
#   ToBookExcursion (call_E5gPZuNaZo2qvJCmeBcuOdID)
#  Call ID: call_E5gPZuNaZo2qvJCmeBcuOdID
#   Args:
#     location: Kunsthaus Zürich
#     request: Book a visit to Kunsthaus Zürich for the second day of the stay.
# Currently in:  book_excursion
# ================================= Tool Message =================================
#
# The assistant is now the Trip Recommendation Assistant. Reflect on the above conversation between the host assistant and the user. The user's intent is unsatisfied. Use the provided tools to assist the user. Remember, you are Trip Recommendation Assistant, and the booking, update, other other action is not complete until after you have successfully invoked the appropriate tool. If the user changes their mind or needs help for other tasks, call the CompleteOrEscalate function to let the primary host assistant take control. Do not mention who you are - just act as the proxy for the assistant.
# Currently in:  book_excursion
# ================================== Ai Message ==================================
# Tool Calls:
#   book_excursion (call_vhtpjSxxEL19bXTSR4szIHpF)
#  Call ID: call_vhtpjSxxEL19bXTSR4szIHpF
#   Args:
#     recommendation_id: 1
